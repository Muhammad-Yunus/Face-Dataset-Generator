# %%
import cv2
import numpy as np
import time

name = input("Masukan nama untuk foto wajah :")
max_image = int(input("Masukan banyaknya foto yang ingin diambil :"))

h, w = 480, 640
black = np.zeros((h,w,3), dtype=np.uint8)
foto = black

folder_data = "photo/"

#image frame
ymin, ymax = h//2 - 125, h//2 + 125
xmin, xmax = w//2 - 125, w//2 + 125

n_image = 0 
capture_delay = 2 # second

filename = ''
label_frame = ''

cap = cv2.VideoCapture(0)
cap.set(3,w)
cap.set(4,h)

last_time = time.time()

def close():
    cap.release()
    cv2.destroyAllWindows()
    
def box(img):
    cv2.rectangle(img, (xmin-1, ymin-21), (xmax+1, ymin-1), (0,255,0),-1)
    cv2.putText(img, label_frame, (xmin+6, ymin-4), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)  
    cv2.rectangle(img,(xmin-1, ymin-1),(xmax+1, ymax+1),(0,255,0),1)
    cv2.rectangle(img, (xmin-1, ymax+1), (xmax+1, ymax+26), (0,255,0),-1)
    cv2.putText(img, "posisikan wajah pada bingkai..", 
                (xmin+6, ymax+16), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1) 
    return img

while(True):
    try :
        ret, frame = cap.read()
        if filename == '' and (time.time() - last_time):
            label_frame = 'Next Capture in ' + str(int(capture_delay - (time.time() - last_time)))
        else :
            label_frame = filename
        
        frame = box(frame)
        
        cv2.imshow('frame',np.hstack((frame, foto)))
        
        if (time.time() - last_time) > capture_delay :
            last_time = time.time()
            filename = name + "-" + str(n_image) + ".png"
            n_image = n_image + 1
            foto[ymin:ymax, xmin:xmax] = frame[ymin:ymax, xmin:xmax]
            
            cv2.imwrite(folder_data + filename, frame[ymin:ymax, xmin:xmax])
            print(filename, " saved!")
            
        if (time.time() - last_time) > capture_delay*0.25 :
            foto = black
            filename = ""

        if (cv2.waitKey(1) & 0xFF == ord('q')) or (n_image >= max_image):
            close()
            break
            
    except Exception as e: 
        print(e)     
        close()
        break
# Out:
# Masukan nama untuk foto wajah :0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\envs\ROOT\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     883             try:
# --> 884                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     885             except Exception:
#
# ~\Anaconda3\envs\ROOT\lib\site-packages\jupyter_client\session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~\Anaconda3\envs\ROOT\lib\site-packages\zmq\sugar\socket.py in recv_multipart(self, flags, copy, track)
#     474         """
# --> 475         parts = [self.recv(flags, copy=copy, track=track)]
#     476         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~\Anaconda3\envs\ROOT\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-b8850c143dee> in <module>
#       3 import time
#       4
# ----> 5 name = input("Masukan nama untuk foto wajah :")
#       6 max_image = int(input("Masukan banyaknya foto yang ingin diambil :"))
#       7
#
# ~\Anaconda3\envs\ROOT\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     857             self._parent_ident,
#     858             self._parent_header,
# --> 859             password=False,
#     860         )
#     861
#
# ~\Anaconda3\envs\ROOT\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     887             except KeyboardInterrupt:
#     888                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 889                 raise KeyboardInterrupt
#     890             else:
#     891                 break
#
# KeyboardInterrupt:
